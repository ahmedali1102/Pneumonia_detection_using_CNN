# %% [markdown]
# <h1>Pneumonia detection using Convolutional neural networks</h1>

# %% [markdown]
# The dataset used here is chest xray dataset which is preprocessed.
# You can find the **Dataset** [here.](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia)

# %% [markdown]
# The dataset consists of :
#
#
# *   5216 training images of which 3815 are of Pneumonia and 1341 are normal images.
# *   624 testing images of which 390 are of Pneumonia and 234 are normal.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
import cv2
from keras.preprocessing.image import img_to_array

# %% [markdown]
# The below mentioned google.colab import drive is used to import drive to colab and drive.mount is used to mount data which is present in drive, so that we can access it.

# %% [markdown]
# **Training data.**

# %%
train_images = r"C:\Users\Ahmed Ali\OneDrive\Desktop\data science notes\5Projects\PNEUMONIA-DETECTION\chest_xray\chest_xray\train"

# %% [markdown]
# **Creating the train data generator.**

# %%
# Initialize ImageDataGenerator with any desired data augmentation or preprocessing parameters
train_datagen = ImageDataGenerator(
    rescale=1./255,            # Rescale pixel values to be between 0 and 1
    shear_range=0.2,           # Shear angle for shear augmentation
    zoom_range=0.2,            # Zoom range for zoom augmentation
    horizontal_flip=True)

# %% [markdown]
# Here every image is resized to (300,300)

# %%
train_generator = train_datagen.flow_from_directory(
    train_images,              # Directory containing training images
    target_size=(300, 300),    # Resize images to 300x300
    batch_size=128,            # Batch size
    class_mode='binary'        # Class mode (binary classification)
)
# Out:
# Found 5216 images belonging to 2 classes.

# %% [markdown]
# **Model outputs :**
#
# 0 : Normal condition
#
# 1 : Pneumonia condition

# %%
train_generator.class_indices
# Out:
# {'NORMAL': 0, 'PNEUMONIA': 1}

# %% [markdown]
# **Validation data generator and loading validation data**

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
validation_generator = test_datagen.flow_from_directory(r"C:\Users\Ahmed Ali\OneDrive\Desktop\data science notes\5Projects\PNEUMONIA-DETECTION\chest_xray\chest_xray\val",
    target_size= (300,300),
    batch_size = 128,
    class_mode = 'binary')
# Out:
# Found 16 images belonging to 2 classes.

# %% [markdown]
# **Plotting :** Images with Pneumonia from dataset.

# %%
#Pneumonia
plot_image = plt.figure(figsize=(10,10))

plot1 = plot_image.add_subplot(3,2,1)
plot2 = plot_image.add_subplot(3,2,2)
plot3 = plot_image.add_subplot(3,2,3)
plot4 = plot_image.add_subplot(3,2,4)
plot5 = plot_image.add_subplot(3,2,5)
plot6 = plot_image.add_subplot(3,2,6)
plot1.matshow(plt.imread(train_generator.filepaths[41]))
plot2.matshow(plt.imread(train_generator.filepaths[176]))
plot3.matshow(plt.imread(train_generator.filepaths[1553]))
plot4.matshow(plt.imread(train_generator.filepaths[354]))
plot5.matshow(plt.imread(train_generator.filepaths[2679]))
plot6.matshow(plt.imread(train_generator.filepaths[2710]))

# %% [markdown]
# **Plotting :** Images without Pneumonia from dataset.

# %%
#Normal
plot_image = plt.figure(figsize=(10,10))

plot1 = plot_image.add_subplot(3,2,1)
plot2 = plot_image.add_subplot(3,2,2)
plot3 = plot_image.add_subplot(3,2,3)
plot4 = plot_image.add_subplot(3,2,4)
plot5 = plot_image.add_subplot(3,2,5)
plot6 = plot_image.add_subplot(3,2,6)
plot1.matshow(plt.imread(train_generator.filepaths[1419]))
plot2.matshow(plt.imread(train_generator.filepaths[1365]))
plot3.matshow(plt.imread(train_generator.filepaths[1400]))
plot4.matshow(plt.imread(train_generator.filepaths[1350]))
plot5.matshow(plt.imread(train_generator.filepaths[1345]))
plot6.matshow(plt.imread(train_generator.filepaths[1349]))

# %% [markdown]
# <h1>Neural Networks using TensorFlow</h1>
#
# Metrics : Accuracy.

# %%
model= tf.keras.models.Sequential([
                                   tf.keras.layers.Conv2D(16, (3,3), activation= 'relu', input_shape= (300, 300, 3)),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   tf.keras.layers.Conv2D(32, (3,3), activation= 'relu'),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   tf.keras.layers.Conv2D(64, (3,3), activation= 'relu'),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   tf.keras.layers.Conv2D(128, (3,3), activation= 'relu'),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   tf.keras.layers.Conv2D(128, (3,3), activation= 'relu'),
                                   tf.keras.layers.MaxPool2D(2,2),

                                   tf.keras.layers.Flatten(),
                                   tf.keras.layers.Dense(256, activation= 'relu'),
                                   tf.keras.layers.Dense(512, activation= 'relu'),
                                   tf.keras.layers.Dense(1, activation= 'sigmoid')
])
model.summary()
model.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics = ['accuracy','Precision','Recall',])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 298, 298, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 149, 149, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 147, 147, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 73, 73, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 35, 35, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 33, 33, 128)       73856
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 128)       147584
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 256)               1605888
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1983009 (7.56 MB)
# Trainable params: 1983009 (7.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Training the model for 50 epochs**

# %%
history = model.fit(train_generator, epochs = 25, validation_data = validation_generator)
# Out:
# Epoch 1/25
# 41/41 [==============================] - 435s 10s/step - loss: 0.5687 - accuracy: 0.7508 - precision: 0.7542 - recall: 0.9858 - val_loss: 0.7124 - val_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 2/25
# 41/41 [==============================] - 285s 7s/step - loss: 0.2979 - accuracy: 0.8792 - precision: 0.9102 - recall: 0.9290 - val_loss: 0.3548 - val_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 3/25
# 41/41 [==============================] - 284s 7s/step - loss: 0.2391 - accuracy: 0.9011 - precision: 0.9305 - recall: 0.9368 - val_loss: 0.6625 - val_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 4/25
# 41/41 [==============================] - 299s 7s/step - loss: 0.1924 - accuracy: 0.9254 - precision: 0.9478 - recall: 0.9520 - val_loss: 0.4593 - val_accuracy: 0.7500 - val_precision: 0.7000 - val_recall: 0.8750
# Epoch 5/25
# 41/41 [==============================] - 271s 7s/step - loss: 0.1805 - accuracy: 0.9321 - precision: 0.9520 - recall: 0.9569 - val_loss: 0.5330 - val_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 6/25
# 41/41 [==============================] - 241s 6s/step - loss: 0.1704 - accuracy: 0.9365 - precision: 0.9569 - recall: 0.9577 - val_loss: 0.5287 - val_accuracy: 0.6875 - val_precision: 0.6364 - val_recall: 0.8750
# Epoch 7/25
# 41/41 [==============================] - 229s 6s/step - loss: 0.1582 - accuracy: 0.9400 - precision: 0.9593 - recall: 0.9600 - val_loss: 0.6671 - val_accuracy: 0.5625 - val_precision: 0.5385 - val_recall: 0.8750
# Epoch 8/25
# 41/41 [==============================] - 3710s 93s/step - loss: 0.1458 - accuracy: 0.9459 - precision: 0.9610 - recall: 0.9665 - val_loss: 0.8569 - val_accuracy: 0.5625 - val_precision: 0.5333 - val_recall: 1.0000
# Epoch 9/25
# 41/41 [==============================] - 209s 5s/step - loss: 0.1335 - accuracy: 0.9473 - precision: 0.9644 - recall: 0.9646 - val_loss: 0.7685 - val_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 10/25
# 41/41 [==============================] - 209s 5s/step - loss: 0.1285 - accuracy: 0.9511 - precision: 0.9667 - recall: 0.9675 - val_loss: 0.7021 - val_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 11/25
# 41/41 [==============================] - 198s 5s/step - loss: 0.1309 - accuracy: 0.9511 - precision: 0.9679 - recall: 0.9662 - val_loss: 0.4120 - val_accuracy: 0.8125 - val_precision: 0.7273 - val_recall: 1.0000
# Epoch 12/25
# 41/41 [==============================] - 203s 5s/step - loss: 0.1161 - accuracy: 0.9534 - precision: 0.9693 - recall: 0.9680 - val_loss: 0.6760 - val_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 13/25
# 41/41 [==============================] - 202s 5s/step - loss: 0.1332 - accuracy: 0.9517 - precision: 0.9685 - recall: 0.9665 - val_loss: 0.8499 - val_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 14/25
# 41/41 [==============================] - 203s 5s/step - loss: 0.1148 - accuracy: 0.9569 - precision: 0.9728 - recall: 0.9690 - val_loss: 1.1896 - val_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 15/25
# 41/41 [==============================] - 198s 5s/step - loss: 0.1042 - accuracy: 0.9613 - precision: 0.9747 - recall: 0.9732 - val_loss: 0.5348 - val_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 16/25
# 41/41 [==============================] - 198s 5s/step - loss: 0.1100 - accuracy: 0.9582 - precision: 0.9733 - recall: 0.9703 - val_loss: 1.3053 - val_accuracy: 0.5625 - val_precision: 0.5333 - val_recall: 1.0000
# Epoch 17/25
# 41/41 [==============================] - 198s 5s/step - loss: 0.1175 - accuracy: 0.9580 - precision: 0.9733 - recall: 0.9701 - val_loss: 0.2464 - val_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000
# Epoch 18/25
# 41/41 [==============================] - 198s 5s/step - loss: 0.1051 - accuracy: 0.9609 - precision: 0.9764 - recall: 0.9708 - val_loss: 0.5956 - val_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 19/25
# 41/41 [==============================] - 208s 5s/step - loss: 0.0959 - accuracy: 0.9630 - precision: 0.9755 - recall: 0.9747 - val_loss: 0.2215 - val_accuracy: 0.8750 - val_precision: 0.8000 - val_recall: 1.0000
# Epoch 20/25
# 41/41 [==============================] - 218s 5s/step - loss: 0.0959 - accuracy: 0.9655 - precision: 0.9792 - recall: 0.9742 - val_loss: 0.1698 - val_accuracy: 0.9375 - val_precision: 0.8889 - val_recall: 1.0000
# Epoch 21/25
# 41/41 [==============================] - 200s 5s/step - loss: 0.0974 - accuracy: 0.9645 - precision: 0.9775 - recall: 0.9747 - val_loss: 0.4809 - val_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 22/25
# 41/41 [==============================] - 221s 5s/step - loss: 0.0971 - accuracy: 0.9651 - precision: 0.9782 - recall: 0.9747 - val_loss: 0.8024 - val_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 23/25
# 41/41 [==============================] - 202s 5s/step - loss: 0.0821 - accuracy: 0.9688 - precision: 0.9793 - recall: 0.9786 - val_loss: 0.5314 - val_accuracy: 0.7500 - val_precision: 0.6667 - val_recall: 1.0000
# Epoch 24/25
# 41/41 [==============================] - 204s 5s/step - loss: 0.0847 - accuracy: 0.9663 - precision: 0.9788 - recall: 0.9757 - val_loss: 0.4727 - val_accuracy: 0.6875 - val_precision: 0.6154 - val_recall: 1.0000
# Epoch 25/25
# 41/41 [==============================] - 200s 5s/step - loss: 0.0892 - accuracy: 0.9668 - precision: 0.9793 - recall: 0.9760 - val_loss: 0.9822 - val_accuracy: 0.6250 - val_precision: 0.5714 - val_recall: 1.0000

# %% [markdown]
# <h2>Accuracy : 98.16%</h2>

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

# %% [markdown]
# **<h3>Plotting Loss Vs Num. of Epochs</h3>**

# %%
plt.figure(figsize=(15, 10))
plt.plot(loss)
plt.plot(val_loss)
plt.legend(['Training loss','Validation loss'], fontsize=16)
plt.title("Loss Vs Epochs", fontsize=18)
plt.xlabel("Num. of Epochs", fontsize=16)
plt.ylabel("Loss", fontsize=16)
print("Loss Vs Num. of Epochs")
print("Training Loss : 0.0519","\nValue loss : 0.0701")
plt.show()
# Out:
# Loss Vs Num. of Epochs
# Training Loss : 0.0519
# Value loss : 0.0701

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# %% [markdown]
# **<h3>Plotting Accuracy Vs Num. of Epochs</h3>**

# %%
plt.figure(figsize=(15, 10))
plt.plot(acc)
plt.plot(val_acc)
plt.legend(['Training accuracy','Validation accuracy'], fontsize=16)
plt.title("Accuracy Vs Epochs", fontsize=18)
plt.xlabel("Num. of Epochs", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
print("Accuracy Vs Epochs")
print("Training accuracy : 0.9816","\nValue accuracy : 1.0000")
plt.show()
# Out:
# Accuracy Vs Epochs
# Training accuracy : 0.9816
# Value accuracy : 1.0000

# %% [markdown]
# <h3>Saving the model</h3>

# %%
model.save("trained.h5")
# Out:
# C:\Users\Ahmed Ali\anaconda3\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# <h3>Loading the saved model so that we can load the model which is already saved so lot of time can be saved and it can also be used for deployment.</h3>

# %%
from keras.models import load_model
model = load_model("trained.h5")

# %% [markdown]
# **Loading the test data generator from drive**

# %%
eval_datagen = ImageDataGenerator(rescale = 1/255)

test_generator = eval_datagen.flow_from_directory(
    r"C:\Users\Ahmed Ali\OneDrive\Desktop\data science notes\5Projects\PNEUMONIA-DETECTION\chest_xray\chest_xray\test",
    target_size = (300, 300),
    batch_size = 128, 
    class_mode = 'binary'
)

eval_result = model.evaluate_generator(test_generator, 624)
print('loss :', eval_result[0])
print('accuracy :', eval_result[1])
# Out:
# Found 624 images belonging to 2 classes.
# C:\Users\Ahmed Ali\AppData\Local\Temp\ipykernel_16936\2554301149.py:10: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   eval_result = model.evaluate_generator(test_generator, 624)
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 624 batches). You may need to use the repeat() function when building your dataset.
# loss : 0.3966362178325653
# accuracy : 0.8814102411270142

# %% [markdown]
# The accuracy of test data is : <h3>88.1410%</h3>

# %% [markdown]
# **An image is used from drive for prediction**

# %%
img= cv2.imread(r"C:\Users\Ahmed Ali\OneDrive\Desktop\data science notes\5Projects\PNEUMONIA-DETECTION\chest_xray\chest_xray\test\NORMAL\IM-0001-0001.jpeg")
tempimg = img
img = cv2.resize(img,(300,300))
img = img/255.0
img = img.reshape(1,300,300,3)
model.predict(img)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# array([[0.02480605]], dtype=float32)

# %% [markdown]
# The prediction shows value as **0.02** which is less than 0.5
#
# so our model has to predict it as Normal which is done below.

# %%
prediction = model.predict(img) >= 0.5
if prediction>=0.5:
    prediction = "Pneumonia"
else:
    prediction = "Normal"
print("Prediction: "+prediction)
plt.imshow(tempimg)
plt.title("Prediction: "+prediction, fontsize=14)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Prediction: Normal
# Text(0.5, 1.0, 'Prediction: Normal')

# %%
img= cv2.imread(r"C:\Users\Ahmed Ali\OneDrive\Desktop\data science notes\5Projects\PNEUMONIA-DETECTION\chest_xray\chest_xray\test\PNEUMONIA\person104_bacteria_492.jpeg")
tempimg = img
img = cv2.resize(img,(300,300))
img = img/255.0
img = img.reshape(1,300,300,3)
model.predict(img)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# array([[0.99999535]], dtype=float32)

# %% [markdown]
# Here another image is used and the model predicted it as **0.999** which is greater than 0.5.
#
# so it have be Pneumonia image which is predicted below.

# %%
prediction = model.predict(img) >= 0.5
if prediction>=0.5:
    prediction = "Pneumonia"
else:
    prediction = "Normal"
print("Prediction: "+prediction)
plt.imshow(tempimg)
plt.title("Prediction: "+prediction, fontsize=14)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# Prediction: Pneumonia
# Text(0.5, 1.0, 'Prediction: Pneumonia')

# %% [markdown]
# <h2>Conclusion :</h2>
#
# This model can be used in Healthcare industry in the radiological department.
#
# It can be deployed to Xray machines.
#
# This can help radiologist to predict the chest xray images easily and accurately.
